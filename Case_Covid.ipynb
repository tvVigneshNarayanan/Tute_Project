# %% [markdown]
# <a href="https://colab.research.google.com/github/tvVigneshNarayanan/Tute_Project/blob/main/Case_Covid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset  = pd.read_csv("/content/covid19_Confirmed_dataset.csv")
dataset.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
dataset.shape
# Out:
# (266, 104)

# %%
df = dataset.drop(["Lat","Long"],axis=1,inplace=True)

# %%
dataset.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
covid_data_aggregate = dataset.groupby("Country/Region").sum()
# Out:
# <ipython-input-9-012e573e545f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   covid_data_aggregate = dataset.groupby("Country/Region").sum()

# %%
covid_data_aggregate.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
covid_data_aggregate.loc["France"].plot()
covid_data_aggregate.loc["Netherlands"].plot()
covid_data_aggregate.loc["United Kingdom"].plot()
plt.legend()

# %%
covid_data_aggregate.loc["United Kingdom"].plot()
# Out:
# <Axes: >

# %%
covid_data_aggregate.loc["United Kingdom"][:3].plot()
# Out:
# <Axes: >

# %%
covid_data_aggregate.loc["United Kingdom"].diff().plot()
# Out:
# <Axes: >

# %%
covid_data_aggregate.loc["United Kingdom"].diff().max()
# Out:
# 8733.0

# %%
covid_data_aggregate.loc["France"].diff().max()
# Out:
# 26849.0

# %%
covid_data_aggregate.loc["Netherlands"].diff().max()
# Out:
# 1346.0

# %%
countries = list(covid_data_aggregate.index)
maximum_infected_rates = []
for co in countries:
  maximum_infected_rates.append(covid_data_aggregate.loc[co].diff().max())
covid_data_aggregate["Maximum Infection Rates"]=  maximum_infected_rates

# %%
covid_data_aggregate
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
Covid_data = pd.DataFrame(covid_data_aggregate["Maximum Infection Rates"])

# %%
Covid_data
# Out:
#                     Maximum Infection Rates
# Country/Region
# Afghanistan                           232.0
# Albania                                34.0
# Algeria                               199.0
# Andorra                                43.0
# Angola                                  5.0
# ...                                     ...
# West Bank and Gaza                     66.0
# Western Sahara                          4.0
# Yemen                                   5.0
# Zambia                                  9.0
# Zimbabwe                                8.0
#
# [187 rows x 1 columns]

# %%
Happiness_report = pd.read_csv("/content/worldwide_happiness_report.csv")

# %%
Happiness_report
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
Unnecessary_items = ["Overall rank","Score","Generosity","Perceptions of corruption"]

# %%
Happiness_report.drop(Unnecessary_items,axis = 1, inplace = True)
Happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
Happiness_report.set_index("Country or region",inplace = True)
Happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
Covid_data.shape
# Out:
# (187, 1)

# %%
Happiness_report.shape
# Out:
# (156, 4)

# %%
data = Covid_data.join(Happiness_report, how="inner")
data
# Out:
#              Maximum Infection Rates  GDP per capita  Social support  \
# Afghanistan                    232.0           0.350           0.517
# Albania                         34.0           0.947           0.848
# Algeria                        199.0           1.002           1.160
# Argentina                      291.0           1.092           1.432
# Armenia                        134.0           0.850           1.055
# ...                              ...             ...             ...
# Venezuela                       29.0           0.960           1.427
# Vietnam                         19.0           0.741           1.346
# Yemen                            5.0           0.287           1.163
# Zambia                           9.0           0.578           1.058
# Zimbabwe                         8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %%
data.corr()
# Out:
#                               Maximum Infection Rates  GDP per capita  \
# Maximum Infection Rates                      1.000000        0.250118
# GDP per capita                               0.250118        1.000000
# Social support                               0.191958        0.759468
# Healthy life expectancy                      0.289263        0.863062
# Freedom to make life choices                 0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# Maximum Infection Rates             0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# Maximum Infection Rates                           0.078196
# ...

# %%
x = data["GDP per capita"]
y = data["Maximum Infection Rates"]
sns.scatterplot(data=data, x="GDP per capita", y="Maximum Infection Rates")
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Maximum Infection Rates'>

# %%
sns.regplot(data=data, x="GDP per capita", y="Maximum Infection Rates")
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Maximum Infection Rates'>

# %%
x = data["Social support"]
y = data["Maximum Infection Rates"]
sns.regplot(data=data, x="Social support", y="Maximum Infection Rates")
# Out:
# <Axes: xlabel='Social support', ylabel='Maximum Infection Rates'>

# %%
x = data["Healthy life expectancy"]
y = data["Maximum Infection Rates"]
sns.regplot(data=data, x="Healthy life expectancy", y="Maximum Infection Rates")
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Maximum Infection Rates'>

# %%
x = data["Freedom to make life choices"]
y = data["Maximum Infection Rates"]
sns.regplot(data=data, x="Freedom to make life choices", y="Maximum Infection Rates")
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Maximum Infection Rates'>
